# %% [markdown]
# Final Project: Analyzing Game Statistics to Predict 2022 World Cup Results
# Emma Williamson

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import requests

team_data = pd.read_csv("team_data.csv")
group_stats = pd.read_csv("group_stats.csv")
team_data.head()
# Out:
#         team  players_used  avg_age  possession  games  games_starts  minutes  \
# 0  Argentina            21     28.5        61.6      5            55      480
# 1  Australia            20     28.7        37.8      4            44      360
# 2    Belgium            20     30.6        57.0      3            33      270
# 3     Brazil            26     28.4        56.2      5            55      480
# 4   Cameroon            22     28.0        41.7      3            33      270
#
#    minutes_90s  goals  assists  ...  fouls  fouled  offsides  pens_won  \
# 0          5.3      9        6  ...     59      89        18         3
# 1          4.0      3        3  ...     52      34         1         0
# 2          3.0      1        1  ...     30      35         3         0
# 3          5.3      8        6  ...     63      74         8         1
# 4          3.0      4        4  ...     32      38         2         0
#
#    pens_conceded  own_goals  ball_recoveries  aerials_won  aerials_lost  \
# 0              0          1              226           68            61
# 1              0          0              200           72            72
# 2              1          0              132           33            28
# 3              0          0              271           43            56
# 4              0          0              142           42            36
#
#    aerials_won_pct
# 0             52.7
# 1             50.0
# 2             54.1
# 3             43.4
# 4             53.8
#
# [5 rows x 189 columns]
